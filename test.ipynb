# %%
import pandas as pd
import streamlit as st
from urllib.request import urlopen
from PIL import Image
from json2html import *
import json
from query import SnowLoader, Query
st.set_page_config(layout="wide")
image = Image.open('./assets/os_logo.jpg')

# %%
ob = SnowLoader()
releases = ob.run('''select * from ds_dev_database.influencer.product_release''')
release_dict = releases.set_index('STARTS_AT')['ID'].to_dict()
creators = ob.run('''select * from ds_dev_database.influencer.creator''').set_index('INFLUENCER_HANDLE')

influ_select_from_list = list(creators.index)
release_select_from_list = list(release_dict.keys())
# Out:
# 2022-11-29 18:27:53.767 INFO    snowflake.connector.connection: Snowflake Connector for Python Version: 2.7.11, Python Version: 3.8.13, Platform: macOS-10.16-x86_64-i386-64bit
# 2022-11-29 18:27:53.767 INFO    snowflake.connector.connection: This connection is in OCSP Fail Open Mode. TLS Certificates would be checked for validity and revocation status. Any other Certificate Revocation related exceptions or OCSP Responder failures would be disregarded in favor of connectivity.
# 2022-11-29 18:27:53.768 INFO    snowflake.connector.connection: Setting use_openssl_only mode to False
# 2022-11-29 18:27:57.072 INFO    snowflake.connector.cursor: query: [select * from ds_dev_database.influencer.product_release]
# 2022-11-29 18:27:58.287 INFO    snowflake.connector.cursor: query execution done
# 2022-11-29 18:27:58.293 INFO    snowflake.connector.cursor: query: [select * from ds_dev_database.influencer.creator]
# 2022-11-29 18:27:59.673 INFO    snowflake.connector.cursor: query execution done

# %%
influ_chk = influ_select_from_list[0]
release_chk = release_select_from_list[2]

# %%
dat = Query.get_drop(ob, influ_chk, release_dict[release_chk])
# Out:
# 2022-11-29 18:31:14.922 INFO    snowflake.connector.cursor: query: [with drops as ( select m.creator_id, m.discount_percentage, m.assignment, m.sort...]
# 2022-11-29 18:31:15.145 INFO    snowflake.connector.cursor: query execution done

# %%
dat[dat['STATUS']=='scroll']
# Out:
#              CREATOR_ID  DISCOUNT_PERCENTAGE                  ASSIGNMENT  \
# 10    chelseaericasmith                  0.2  Test Drop 10 drops w/ cogs
# 11    chelseaericasmith                  1.0  Test Drop 10 drops w/ cogs
# 12    chelseaericasmith                  1.0  Test Drop 10 drops w/ cogs
# 13    chelseaericasmith                  0.2  Test Drop 10 drops w/ cogs
# 14    chelseaericasmith                  1.0  Test Drop 10 drops w/ cogs
# ...                 ...                  ...                         ...
# 2934  chelseaericasmith                  1.0  Test Drop 10 drops w/ cogs
# 2935  chelseaericasmith                  1.0  Test Drop 10 drops w/ cogs
# 2936  chelseaericasmith                  0.2  Test Drop 10 drops w/ cogs
# 2937  chelseaericasmith                  0.2  Test Drop 10 drops w/ cogs
# 2938  chelseaericasmith                  1.0  Test Drop 10 drops w/ cogs
#
#       SORT_ORDER     PRODUCT_ID  \
# 10             0      114589574
# 11             0      114589574
# 12             1  4703793545353
# 13             1  4703793545353
# 14             2  6583754719286
# ...          ...            ...
# 2934        1462  4912281419878
# 2935        1463  6792410398822
# 2936        1463  6792410398822
# 2937        1464  6792397520998
# 2938        1464  6792397520998
#
#                                         COLLAB_METADATA  \
# 10                                                 None
# 11                                                 None
# 12    {"descriptions":[{"icon": "camera","text":"1 R...
# 13    {"descriptions":[{"icon": "camera","text":"1 R...
# 14    {"descriptions":[{"icon": "camera","text":"1 R...
# ...                                                 ...
# 2934  {"descriptions":[{"icon": "camera","text":"1 R...
# 2935  {"descriptions":[{"icon": "camera","text":"1 R...
# 2936  {"descriptions":[{"icon": "camera","text":"1 R...
# 2937  {"descriptions":[{"icon": "camera","text":"1 R...
# 2938  {"descriptions":[{"icon": "camera","text":"1 R...
#
#                                                IMAGEURL  PRODUCT_GROSS_MARGIN  \
# 10    https://cdn.shopify.com/s/files/1/0200/5278/pr...              0.271190
# 11    https://cdn.shopify.com/s/files/1/0200/5278/pr...              0.271190
# 12    https://cdn.shopify.com/s/files/1/2119/7595/pr...              0.710157
# 13    https://cdn.shopify.com/s/files/1/2119/7595/pr...              0.710157
# 14    https://cdn.shopify.com/s/files/1/1172/1406/pr...              0.532879
# ...                                                 ...                   ...
# 2934  https://cdn.shopify.com/s/files/1/1944/7205/pr...              0.601788
# 2935  https://cdn.shopify.com/s/files/1/1944/7205/pr...              0.596524
# 2936  https://cdn.shopify.com/s/files/1/1944/7205/pr...              0.596524
# 2937  https://cdn.shopify.com/s/files/1/1944/7205/pr...              0.602695
# 2938  https://cdn.shopify.com/s/files/1/1944/7205/pr...              0.602695
#
#       BREAKEVEN_DISCOUNT_PCT  MAX_CLAIMED_COUNT GENDER_CLEANED    PRICE  \
# 10                  0.271190              420.0              U  1599.99
# 11                  0.271190              420.0              U  1599.99
# 12                  0.710157              420.0              F    76.00
# 13                  0.710157              420.0              F    76.00
# 14                  0.532879               31.0              F   695.00
# ...                      ...                ...            ...      ...
# 2934                0.601788              420.0              U   483.99
# 2935                0.596524              420.0              U   547.99
# 2936                0.596524              420.0              U   547.99
# 2937                0.602695              420.0              U   949.99
# 2938                0.602695              420.0              U   949.99
#
#                    PRODUCT_TITLE       OS_MERCHANT  STATUS
# 10    10" Organic Latex Mattress  Spindle Mattress  scroll
# 11    10" Organic Latex Mattress  Spindle Mattress  scroll
# 12                  The Bathpack          Bathpack  scroll
# 13                  The Bathpack          Bathpack  scroll
# 14            LW Gold Ball Chain  Livewell Designs  scroll
# ...                          ...               ...     ...
# 2934               Snoop Vuitton   Canvas Cultures  scroll
# 2935                        Lion   Canvas Cultures  scroll
# 2936                        Lion   Canvas Cultures  scroll
# 2937            AP Skeleton Rose   Canvas Cultures  scroll
# 2938            AP Skeleton Rose   Canvas Cultures  scroll
#
# [2929 rows x 15 columns]

# %%
release_dict[release_chk]
# Out:
# '7852ed9a-8e57-42ac-af73-cf639f8f3f39'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 drops = Query.get_drop(ob, influ_chk, release_dict[release_chk])
#
# AttributeError: type object 'Query' has no attribute 'get_drop'

# %%
def cacherecos(_s, influ_chk, release_dict, release_chk, max_recs):
    
    

    data = []
    for val in range(0,max_recs,1):
        try:
            img = Image.open(urlopen(drops.iloc[val]['IMAGEURL']))
            caption = drops.iloc[val]['STATUS'] +' | ' + drops.iloc[val]['OS_MERCHANT'] + ' | ' + drops.iloc[val]['PRODUCT_TITLE'] + ' | Price : ${:.2f}'.format(drops.iloc[val]['PRICE']) + ' | % Discount : ' + str(drops.iloc[val]['DISCOUNT_PERCENTAGE']*100) + '% | Gross Margin : {:.2%}'.format(drops.iloc[val]['PRODUCT_GROSS_MARGIN'])
            product_id = drops.iloc[val]['PRODUCT_ID']
            if drops.iloc[val]['STATUS'] == 'drop':
                try:
                    description = json2html.convert(json =json.loads(drops.iloc[val]['COLLAB_METADATA']))
                except:
                    description = '<b>DROP</b>'
            else:
                description = '<b>SCROLL</b>'
        except:
            pass
        data.append((img, caption, product_id, description))

    return [data, drops]
